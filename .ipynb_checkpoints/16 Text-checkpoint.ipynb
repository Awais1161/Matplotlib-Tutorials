# %%
import matplotlib.pyplot as plt

x=[1,2,3,4,5]
y=[3,1,5,2,6]

plt.plot(x,y)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x=[1,2,3,4,5]
y=[3,1,5,2,6]

plt.plot(x,y)


plt.title('popularity',fontsize=20)
plt.xlabel('x',fontsize=20)
plt.ylabel('y',fontsize=20)
plt.show()

# %%
x=[1,2,3,4,5]
y=[3,1,5,2,6]

plt.plot(x,y)


plt.title('popularity',fontsize=20)
plt.xlabel('x',fontsize=20)
plt.ylabel('y',fontsize=20)

plt.text(2,4,'python')

plt.show()

# %%
x=[1,2,3,4,5]
y=[3,1,5,2,6]

plt.plot(x,y)


plt.title('popularity',fontsize=20)
plt.xlabel('x',fontsize=20)
plt.ylabel('y',fontsize=20)

plt.text(2,4,'java',fontsize=20,color='r',style='italic')

plt.show()

# %%
x=[1,2,3,4,5]
y=[3,1,5,2,6]

plt.plot(x,y)


plt.title('popularity',fontsize=20)
plt.xlabel('x',fontsize=20)
plt.ylabel('y',fontsize=20)

plt.text(2,4,'java',fontsize=20,color='r',bbox={})

plt.show()

# %%
x=[1,2,3,4,5]
y=[3,1,5,2,6]

plt.plot(x,y)


plt.title('popularity',fontsize=20)
plt.xlabel('x',fontsize=20)
plt.ylabel('y',fontsize=20)

plt.text(2,4,'java',fontsize=20,color='r',bbox={'facecolor':'g'})

plt.show()

# %%
x=[1,2,3,4,5]
y=[3,1,5,2,6]

plt.plot(x,y)


plt.title('popularity',fontsize=20)
plt.xlabel('x',fontsize=20)
plt.ylabel('y',fontsize=20)

plt.text(2,4,'java',fontsize=20,color='r',bbox={'facecolor':'g'})

plt.annotate('python',xy=(3,2),xytext=(4,4),arrowprops=dict(facecolor='black',shrink=100))
plt.show()

# %%
x=[1,2,3,4,5]
y=[3,1,5,2,6]

plt.plot(x,y)


plt.title('popularity',fontsize=20)
plt.xlabel('x',fontsize=20)
plt.ylabel('y',fontsize=20)

plt.text(2,4,'java',fontsize=20,color='r',bbox={'facecolor':'g'})

plt.annotate('python',xy=(3,2),xytext=(4,4),arrowprops=dict(facecolor='black')) # no shrink
plt.show()

# %%
x=[1,2,3,4,5]
y=[3,1,5,2,6]

plt.plot(x,y)


plt.title('popularity',fontsize=20)
plt.xlabel('x',fontsize=20)
plt.ylabel('y',fontsize=20)

plt.text(2,4,'java',fontsize=20,color='r',bbox={'facecolor':'g'})

plt.annotate('python',xy=(2,1),xytext=(4,4),arrowprops=dict(facecolor='black')) 
plt.show()

# %%
x=[1,2,3,4,5]
y=[3,1,5,2,6]

plt.plot(x,y)


plt.title('popularity',fontsize=20)
plt.xlabel('x',fontsize=20)
plt.ylabel('y',fontsize=20)

plt.text(2,4,'java',fontsize=20,color='r',bbox={'facecolor':'g'})

plt.annotate('python',xy=(2,1),xytext=(3,3),arrowprops=dict(facecolor='black')) 
plt.show()

# %%
x=[1,2,3,4,5]
y=[3,1,5,2,6]

plt.plot(x,y)


plt.title('popularity',fontsize=20)
plt.xlabel('x',fontsize=20)
plt.ylabel('y',fontsize=20)

plt.text(2,4,'java',fontsize=20,color='r',bbox={'facecolor':'g'})
plt.annotate('python',xy=(2,1),xytext=(3,3),arrowprops=dict(facecolor='black')) 

plt.legend(['up'])
plt.show()

# %%
x=[1,2,3,4,5]
y=[3,1,5,2,6]

plt.plot(x,y)


plt.title('popularity',fontsize=20)
plt.xlabel('x',fontsize=20)
plt.ylabel('y',fontsize=20)

plt.text(2,4,'java',fontsize=20,color='r',bbox={'facecolor':'g'})
plt.annotate('python',xy=(2,1),xytext=(3,3),arrowprops=dict(facecolor='black')) 

plt.legend(['up'],loc=9) # loc varies fro 0 to 10
plt.show()

# %%
x=[1,2,3,4,5]
y=[3,1,5,2,6]

plt.plot(x,y)


plt.title('popularity',fontsize=20)
plt.xlabel('x',fontsize=20)
plt.ylabel('y',fontsize=20)

plt.text(2,4,'java',fontsize=20,color='r',bbox={'facecolor':'g'})
plt.annotate('python',xy=(2,1),xytext=(3,3),arrowprops=dict(facecolor='black')) 

plt.legend(['up'],loc=9, facecolor='m') 
plt.show()

# %%
x=[1,2,3,4,5]
y=[3,1,5,2,6]

plt.plot(x,y)


plt.title('popularity',fontsize=20)
plt.xlabel('x',fontsize=20)
plt.ylabel('y',fontsize=20)

plt.text(2,4,'java',fontsize=20,color='r',bbox={'facecolor':'g'})
plt.annotate('python',xy=(2,1),xytext=(3,3),arrowprops=dict(facecolor='black')) 

plt.legend(['up'],loc=9, facecolor='m',edgecolor='r') 
plt.show()

# %%
x=[1,2,3,4,5]
y=[3,1,5,2,6]

plt.plot(x,y)


plt.title('popularity',fontsize=20)
plt.xlabel('x',fontsize=20)
plt.ylabel('y',fontsize=20)

plt.text(2,4,'java',fontsize=20,color='r',bbox={'facecolor':'g'})
plt.annotate('python',xy=(2,1),xytext=(3,3),arrowprops=dict(facecolor='black')) 

plt.legend(['up'],loc=9, facecolor='m',edgecolor='r', framealpha=0.5) 
plt.show()

# %%
x=[1,2,3,4,5]
y=[3,1,5,2,6]

plt.plot(x,y)


plt.title('popularity',fontsize=20)
plt.xlabel('x',fontsize=20)
plt.ylabel('y',fontsize=20)

plt.text(2,4,'java',fontsize=20,color='r',bbox={'facecolor':'g'})
plt.annotate('python',xy=(2,1),xytext=(3,3),arrowprops=dict(facecolor='black')) 

plt.legend(['up'],loc=9, facecolor='m',edgecolor='r', framealpha=0.5,shadow=True) 
plt.show()
