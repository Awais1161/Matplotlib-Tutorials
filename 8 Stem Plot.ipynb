# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6]
y=[2,2,5,6,4,3]
plt.stem(x,y)
plt.show()

# %%
x=[1,2,3,4,5,6]
y=[2,2,5,6,4,3]
plt.stem(x,y,linefmt=':')
plt.show()

# %%
x=[1,2,3,4,5,6]
y=[2,2,5,6,4,3]
plt.stem(x,y,linefmt=':', markerfmt='r')
plt.show()

# %%
x=[1,2,3,4,5,6]
y=[2,2,5,6,4,3]
plt.stem(x,y,linefmt=':', markerfmt='r+')
plt.show()

# %%
x=[1,2,3,4,5,6]
y=[2,2,5,6,4,3]
plt.stem(x,y,linefmt=':', markerfmt='ro')  # o by default
plt.show()

# %%
x=[1,2,3,4,5,6]
y=[2,2,5,6,4,3]
plt.stem(x,y,linefmt=':', markerfmt='ro', bottom=1)  
plt.show()

# %%
x=[1,2,3,4,5,6]
y=[2,2,5,6,4,3]
plt.stem(x,y,linefmt=':', markerfmt='ro', bottom=2)  
plt.show()

# %%
x=[1,2,3,4,5,6]
y=[2,2,5,6,4,3]
plt.stem(x,y,linefmt=':', markerfmt='ro', bottom=9)  
plt.show()

# %%
x=[1,2,3,4,5,6]
y=[2,2,5,6,4,3]
plt.stem(x,y,linefmt=':', markerfmt='ro', bottom=0,basefmt='g')  
plt.show()

# %%
x=[1,2,3,4,5,6]
y=[2,2,5,6,4,3]
plt.stem(x,y,linefmt=':', markerfmt='ro', bottom=0,basefmt='g', label='python') 
plt.legend()
plt.show()

# %%
x=[1,2,3,4,5,6]
y=[2,2,5,6,4,3]
plt.stem(x,y,linefmt=':', markerfmt='ro', bottom=0,basefmt='g', label='python', use_line_collection=False)  # default is True
plt.legend()
plt.show()

# %%
x=[1,2,3,4,5,6]
y=[2,2,5,6,4,3]
plt.stem(x,y,linefmt=':', markerfmt='ro', bottom=0,basefmt='g', label='python', use_line_collection=False,
         orientation='horizontal') 
plt.legend()
plt.show()
