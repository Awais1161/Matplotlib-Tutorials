# %%
# syntex
x=[]
plt.hist()
lpt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np 
import random
x=np.random.randint(10,60,(50))  
print(x)
# Out:
# [28 54 20 23 51 32 28 19 41 38 34 18 54 59 46 32 56 15 41 30 45 11 11 53
#  36 46 36 25 26 57 12 57 15 10 29 15 23 28 15 29 34 19 58 20 46 40 29 52
#  29 38]

# %%
d=[58, 29, 59, 30, 33, 14, 45, 49, 30, 28, 43, 44, 23, 37, 33, 47, 26, 43, 32, 33, 56, 35, 50, 52,
 45, 21, 50, 50, 36, 25, 56, 34, 25, 10, 26, 36, 58, 13, 14, 50, 21, 42, 50, 27, 16, 51, 19, 15,
 48, 16]

plt.hist(d)

plt.title('Population')
plt.xlabel('python')
plt.ylabel('No.')
plt.show()

# %%
d=[58, 29, 59, 30, 33, 14, 45, 49, 30, 28, 43, 44, 23, 37, 33, 47, 26, 43, 32, 33, 56, 35, 50, 52,
 45, 21, 50, 50, 36, 25, 56, 34, 25, 10, 26, 36, 58, 13, 14, 50, 21, 42, 50, 27, 16, 51, 19, 15,
 48, 16]

plt.hist(d, color='r')

plt.title('Population')
plt.xlabel('python')
plt.ylabel('No.')
plt.show()

# %%
d=[58, 29, 59, 30, 33, 14, 45, 49, 30, 28, 43, 44, 23, 37, 33, 47, 26, 43, 32, 33, 56, 35, 50, 52,
 45, 21, 50, 50, 36, 25, 56, 34, 25, 10, 26, 36, 58, 13, 14, 50, 21, 42, 50, 27, 16, 51, 19, 15,
 48, 16]

b=[10,20,30,40,50,60]
plt.hist(d, color='g', edgecolor='r', bins=b)

plt.title('Population')
plt.xlabel('python')
plt.ylabel('No.')
plt.show()

# %%
d=[58, 29, 59, 30, 33, 14, 45, 49, 30, 28, 43, 44, 23, 37, 33, 47, 26, 43, 32, 33, 56, 35, 50, 52,
 45, 21, 50, 50, 36, 25, 56, 34, 25, 10, 26, 36, 58, 13, 14, 50, 21, 42, 50, 27, 16, 51, 19, 15,
 48, 16]

b=[10,20,30,40,50,60]
plt.hist(d,'auto',  (0,100), edgecolor='r')

plt.title('Population')
plt.xlabel('python')
plt.ylabel('No.')
plt.show()

# %%
d=[58, 29, 59, 30, 33, 14, 45, 49, 30, 28, 43, 44, 23, 37, 33, 47, 26, 43, 32, 33, 56, 35, 50, 52,
 45, 21, 50, 50, 36, 25, 56, 34, 25, 10, 26, 36, 58, 13, 14, 50, 21, 42, 50, 27, 16, 51, 19, 15,
 48, 16]

b=[10,20,30,40,50,60]
plt.hist(d, color='g', edgecolor='r', bins=b, cumulative=-1)

plt.title('Population')
plt.xlabel('python')
plt.ylabel('No.')
plt.show()

# %%
d=[58, 29, 59, 30, 33, 14, 45, 49, 30, 28, 43, 44, 23, 37, 33, 47, 26, 43, 32, 33, 56, 35, 50, 52,
 45, 21, 50, 50, 36, 25, 56, 34, 25, 10, 26, 36, 58, 13, 14, 50, 21, 42, 50, 27, 16, 51, 19, 15,
 48, 16]

b=[10,20,30,40,50,60]
plt.hist(d, color='g', edgecolor='r', bins=b, cumulative=1)

plt.title('Population')
plt.xlabel('python')
plt.ylabel('No.')
plt.show()

# %%
d=[58, 29, 59, 30, 33, 14, 45, 49, 30, 28, 43, 44, 23, 37, 33, 47, 26, 43, 32, 33, 56, 35, 50, 52,
 45, 21, 50, 50, 36, 25, 56, 34, 25, 10, 26, 36, 58, 13, 14, 50, 21, 42, 50, 27, 16, 51, 19, 15,
 48, 16]

b=[10,20,30,40,50,60]
plt.hist(d, color='g', edgecolor='r',  cumulative=-1, bottom=20, align='left')

plt.title('Population')
plt.xlabel('python')
plt.ylabel('No.')
plt.show()

# %%
d=[58, 29, 59, 30, 33, 14, 45, 49, 30, 28, 43, 44, 23, 37, 33, 47, 26, 43, 32, 33, 56, 35, 50, 52,
 45, 21, 50, 50, 36, 25, 56, 34, 25, 10, 26, 36, 58, 13, 14, 50, 21, 42, 50, 27, 16, 51, 19, 15,
 48, 16]

b=[10,20,30,40,50,60]
plt.hist(d, color='g', edgecolor='r',  cumulative=-1, bottom=20, align='mid')

plt.title('Population')
plt.xlabel('python')
plt.ylabel('No.')
plt.show()

# %%
d=[58, 29, 59, 30, 33, 14, 45, 49, 30, 28, 43, 44, 23, 37, 33, 47, 26, 43, 32, 33, 56, 35, 50, 52,
 45, 21, 50, 50, 36, 25, 56, 34, 25, 10, 26, 36, 58, 13, 14, 50, 21, 42, 50, 27, 16, 51, 19, 15,
 48, 16]

b=[10,20,30,40,50,60]
plt.hist(d, color='g', edgecolor='r',  cumulative=-1, bottom=20, align='right')

plt.title('Population')
plt.xlabel('python')
plt.ylabel('No.')
plt.show()

# %%
d=[58, 29, 59, 30, 33, 14, 45, 49, 30, 28, 43, 44, 23, 37, 33, 47, 26, 43, 32, 33, 56, 35, 50, 52,
 45, 21, 50, 50, 36, 25, 56, 34, 25, 10, 26, 36, 58, 13, 14, 50, 21, 42, 50, 27, 16, 51, 19, 15,
 48, 16]

b=[10,20,30,40,50,60]
plt.hist(d, color='g', edgecolor='r',  cumulative=-1, bottom=20, histtype='step')

plt.title('Population')
plt.xlabel('python')
plt.ylabel('No.')
plt.show()

# %%
d=[58, 29, 59, 30, 33, 14, 45, 49, 30, 28, 43, 44, 23, 37, 33, 47, 26, 43, 32, 33, 56, 35, 50, 52,
 45, 21, 50, 50, 36, 25, 56, 34, 25, 10, 26, 36, 58, 13, 14, 50, 21, 42, 50, 27, 16, 51, 19, 15,
 48, 16]

b=[10,20,30,40,50,60]
plt.hist(d, color='g', edgecolor='r',  cumulative=-1, bottom=20, histtype='stepfilled')

plt.title('Population')
plt.xlabel('python')
plt.ylabel('No.')
plt.show()

# %%
d=[58, 29, 59, 30, 33, 14, 45, 49, 30, 28, 43, 44, 23, 37, 33, 47, 26, 43, 32, 33, 56, 35, 50, 52,
 45, 21, 50, 50, 36, 25, 56, 34, 25, 10, 26, 36, 58, 13, 14, 50, 21, 42, 50, 27, 16, 51, 19, 15,
 48, 16]

b=[10,20,30,40,50,60]
plt.hist(d, color='g', edgecolor='r',  cumulative=-1, histtype='barstacked')

plt.title('Population')
plt.xlabel('python')
plt.ylabel('No.')
plt.show()

# %%
d=[58, 29, 59, 30, 33, 14, 45, 49, 30, 28, 43, 44, 23, 37, 33, 47, 26, 43, 32, 33, 56, 35, 50, 52,
 45, 21, 50, 50, 36, 25, 56, 34, 25, 10, 26, 36, 58, 13, 14, 50, 21, 42, 50, 27, 16, 51, 19, 15,
 48, 16]

b=[10,20,30,40,50,60]
plt.hist(d, color='g', edgecolor='r',  cumulative=-1, histtype='bar')

plt.title('Population')
plt.xlabel('python')
plt.ylabel('No.')
plt.show()

# %%
d=[58, 29, 59, 30, 33, 14, 45, 49, 30, 28, 43, 44, 23, 37, 33, 47, 26, 43, 32, 33, 56, 35, 50, 52,
 45, 21, 50, 50, 36, 25, 56, 34, 25, 10, 26, 36, 58, 13, 14, 50, 21, 42, 50, 27, 16, 51, 19, 15,
 48, 16]

b=[10,20,30,40,50,60]
plt.hist(d, color='g', edgecolor='r',  cumulative=-1, histtype='bar', orientation='horizontal') # vertical : by default

plt.title('Population')
plt.xlabel('python')
plt.ylabel('No.')
plt.show()

# %%
d=[58, 29, 59, 30, 33, 14, 45, 49, 30, 28, 43, 44, 23, 37, 33, 47, 26, 43, 32, 33, 56, 35, 50, 52,
 45, 21, 50, 50, 36, 25, 56, 34, 25, 10, 26, 36, 58, 13, 14, 50, 21, 42, 50, 27, 16, 51, 19, 15,
 48, 16]

b=[10,20,30,40,50,60]
plt.hist(d, color='g', edgecolor='r', bins=b, rwidth=0.8)

plt.title('Population')
plt.xlabel('python')
plt.ylabel('No.')
plt.show()

# %%
d=[58, 29, 59, 30, 33, 14, 45, 49, 30, 28, 43, 44, 23, 37, 33, 47, 26, 43, 32, 33, 56, 35, 50, 52,
 45, 21, 50, 50, 36, 25, 56, 34, 25, 10, 26, 36, 58, 13, 14, 50, 21, 42, 50, 27, 16, 51, 19, 15,
 48, 16]

b=[10,20,30,40,50,60]
plt.hist(d, color='g', edgecolor='r', bins=b, rwidth=0.2)

plt.title('Population')
plt.xlabel('python')
plt.ylabel('No.')
plt.show()

# %%
d=[58, 29, 59, 30, 33, 14, 45, 49, 30, 28, 43, 44, 23, 37, 33, 47, 26, 43, 32, 33, 56, 35, 50, 52,
 45, 21, 50, 50, 36, 25, 56, 34, 25, 10, 26, 36, 58, 13, 14, 50, 21, 42, 50, 27, 16, 51, 19, 15,
 48, 16]

b=[10,20,30,40,50,60]
plt.hist(d, color='g', edgecolor='r', bins=b, log=True)

plt.title('Population')
plt.xlabel('python')
plt.ylabel('No.')
plt.show()

# %%
d=[58, 29, 59, 30, 33, 14, 45, 49, 30, 28, 43, 44, 23, 37, 33, 47, 26, 43, 32, 33, 56, 35, 50, 52,
 45, 21, 50, 50, 36, 25, 56, 34, 25, 10, 26, 36, 58, 13, 14, 50, 21, 42, 50, 27, 16, 51, 19, 15,
 48, 16]

b=[10,20,30,40,50,60]
plt.hist(d, color='g', edgecolor='r', bins=b, label='python') # label ka taluq legend se ha

plt.title('Population')
plt.xlabel('python')
plt.ylabel('No.')

plt.legend()
plt.show()

# %%
d=[58, 29, 59, 30, 33, 14, 45, 49, 30, 28, 43, 44, 23, 37, 33, 47, 26, 43, 32, 33, 56, 35, 50, 52,
 45, 21, 50, 50, 36, 25, 56, 34, 25, 10, 26, 36, 58, 13, 14, 50, 21, 42, 50, 27, 16, 51, 19, 15,
 48, 16]

b=[10,20,30,40,50,60]
plt.hist(d, color='g', edgecolor='r', bins=b, label='python') 

plt.title('Population')
plt.xlabel('python')
plt.ylabel('No.')

plt.axvline()
plt.legend()
plt.show()

# %%
d=[58, 29, 59, 30, 33, 14, 45, 49, 30, 28, 43, 44, 23, 37, 33, 47, 26, 43, 32, 33, 56, 35, 50, 52,
 45, 21, 50, 50, 36, 25, 56, 34, 25, 10, 26, 36, 58, 13, 14, 50, 21, 42, 50, 27, 16, 51, 19, 15,
 48, 16]

b=[10,20,30,40,50,60]
plt.hist(d, color='g', edgecolor='r', bins=b, label='python') 
plt.title('Population')
plt.xlabel('python')
plt.ylabel('No.')

plt.axvline(45)
plt.legend()
plt.show()

# %%
d=[58, 29, 59, 30, 33, 14, 45, 49, 30, 28, 43, 44, 23, 37, 33, 47, 26, 43, 32, 33, 56, 35, 50, 52,
 45, 21, 50, 50, 36, 25, 56, 34, 25, 10, 26, 36, 58, 13, 14, 50, 21, 42, 50, 27, 16, 51, 19, 15,
 48, 16]

b=[10,20,30,40,50,60]
plt.hist(d, color='g', edgecolor='r', bins=b, label='python') 

plt.title('Population')
plt.xlabel('python')
plt.ylabel('No.')

plt.axvline(45, color='r')
plt.legend()
plt.show()

# %%
d=[58, 29, 59, 30, 33, 14, 45, 49, 30, 28, 43, 44, 23, 37, 33, 47, 26, 43, 32, 33, 56, 35, 50, 52,
 45, 21, 50, 50, 36, 25, 56, 34, 25, 10, 26, 36, 58, 13, 14, 50, 21, 42, 50, 27, 16, 51, 19, 15,
 48, 16]

b=[10,20,30,40,50,60]
plt.hist(d, color='g', edgecolor='r', bins=b, label='python') 
plt.title('Population')
plt.xlabel('python')
plt.ylabel('No.')

plt.axvline(45, color='r', label='line')
plt.legend()
plt.show()

# %%
d=[58, 29, 59, 30, 33, 14, 45, 49, 30, 28, 43, 44, 23, 37, 33, 47, 26, 43, 32, 33, 56, 35, 50, 52,
 45, 21, 50, 50, 36, 25, 56, 34, 25, 10, 26, 36, 58, 13, 14, 50, 21, 42, 50, 27, 16, 51, 19, 15,
 48, 16]

b=[10,20,30,40,50,60]
plt.hist(d, color='g', edgecolor='r', bins=b, label='python') 

plt.title('Population')
plt.xlabel('python')
plt.ylabel('No.')

plt.axvline(45, color='r', label='line')
plt.grid()
plt.legend()
plt.show()
